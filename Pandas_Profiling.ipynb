# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedarham/XLearnings01/blob/main/Pandas_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import kagglehub
import os
path2 = kagglehub.dataset_download("brendan45774/test-file")

print(os.listdir(path2))

titanic =pd.read_csv(os.path.join(path2, "tested.csv"))
# Out:
# Using Colab cache for faster access to the 'test-file' dataset.
# ['tested.csv']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(titanic)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
#         <iframe
#             width="900"
#             height="500"
#             src="output.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
